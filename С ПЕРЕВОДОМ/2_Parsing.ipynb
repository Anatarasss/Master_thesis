# %%
import os
import json
from langdetect import detect
from deep_translator import GoogleTranslator
import trafilatura

# %%
input_dir = "./"
output_dir = "parsed_articles"
os.makedirs(output_dir, exist_ok=True)

# %%
def detect_language(text):
    try:
        return detect(text)
    except:
        return "unknown"

# %%
def translate_text(text, source_lang):
    if source_lang == "en":
        return text
    try:
        translated = GoogleTranslator(source=source_lang, 
                                      target="en").translate(text)
        return translated
    except:
        return ""

# %%
for filename in os.listdir(input_dir):
    if not filename.endswith(".json"):
        continue

    with open(os.path.join(input_dir, filename), 
              "r", 
              encoding="utf-8") as f:
        articles = json.load(f)

    for article in articles:
        url = article.get("url")
        if not url:
            continue

        downloaded = trafilatura.fetch_url(url)
        if not downloaded:
            continue

        full_text = trafilatura.extract(downloaded, 
                                        include_comments=False, 
                                        include_tables=False)
        if not full_text:
            continue

        lang = detect_language(full_text)
        translated = translate_text(full_text, lang)

        output_data = {
            "title": article.get("title"),
            "published_date": article.get("published date"),
            "url": url,
            "original_language": lang,
            "original_text": full_text,
            "translated_text_en": translated
        }

        base = os.path.splitext(filename)[0]
        out_filename = f"{base}_{articles.index(article)}_parsed.json"
        with open(os.path.join(output_dir, out_filename), 
                  "w", 
                  encoding="utf-8") as f_out:
            json.dump(output_data, f_out, ensure_ascii=False, indent=2)

        print(f"Parsed and saved: {out_filename}")
# Out:
# Parsed and saved: au_articles_0_parsed.json
# Parsed and saved: au_articles_1_parsed.json
# Parsed and saved: au_articles_2_parsed.json
# Parsed and saved: au_articles_3_parsed.json
# Parsed and saved: au_articles_4_parsed.json
# Parsed and saved: au_articles_5_parsed.json
# Parsed and saved: au_articles_6_parsed.json
# Parsed and saved: au_articles_7_parsed.json
# Parsed and saved: au_articles_8_parsed.json
# Parsed and saved: au_articles_9_parsed.json
# Parsed and saved: au_articles_10_parsed.json
# Parsed and saved: au_articles_11_parsed.json
# Parsed and saved: au_articles_12_parsed.json
# Parsed and saved: au_articles_13_parsed.json
# Parsed and saved: au_articles_14_parsed.json
# Parsed and saved: au_articles_15_parsed.json
# Parsed and saved: au_articles_16_parsed.json
# Parsed and saved: au_articles_17_parsed.json
# Parsed and saved: au_articles_18_parsed.json
# Parsed and saved: au_articles_19_parsed.json
# Parsed and saved: au_articles_20_parsed.json
# Parsed and saved: au_articles_21_parsed.json
# Parsed and saved: au_articles_22_parsed.json
# Parsed and saved: au_articles_23_parsed.json
# Parsed and saved: au_articles_24_parsed.json
# Parsed and saved: au_articles_25_parsed.json
# Parsed and saved: au_articles_26_parsed.json
# Parsed and saved: au_articles_27_parsed.json
# Parsed and saved: au_articles_28_parsed.json
# Parsed and saved: au_articles_29_parsed.json
# Parsed and saved: au_articles_30_parsed.json
# Parsed and saved: au_articles_31_parsed.json
# Parsed and saved: au_articles_32_parsed.json
# Parsed and saved: au_articles_33_parsed.json
# Parsed and saved: au_articles_34_parsed.json
# Parsed and saved: au_articles_35_parsed.json
# Parsed and saved: au_articles_36_parsed.json
# Parsed and saved: au_articles_37_parsed.json
# Parsed and saved: au_articles_38_parsed.json
# Parsed and saved: au_articles_39_parsed.json
# Parsed and saved: au_articles_40_parsed.json
# Parsed and saved: au_articles_41_parsed.json
# Parsed and saved: au_articles_42_parsed.json
# Parsed and saved: au_articles_43_parsed.json
# Parsed and saved: au_articles_44_parsed.json
# Parsed and saved: au_articles_45_parsed.json
# Parsed and saved: au_articles_46_parsed.json
# Parsed and saved: au_articles_47_parsed.json
# Parsed and saved: au_articles_48_parsed.json
# Parsed and saved: au_articles_49_parsed.json
# Parsed and saved: br_articles_0_parsed.json
# Parsed and saved: br_articles_1_parsed.json
# Parsed and saved: br_articles_2_parsed.json
# Parsed and saved: br_articles_3_parsed.json
# Parsed and saved: br_articles_4_parsed.json
# Parsed and saved: br_articles_5_parsed.json
# Parsed and saved: br_articles_7_parsed.json
# Parsed and saved: br_articles_8_parsed.json
# Parsed and saved: br_articles_9_parsed.json
# Parsed and saved: br_articles_10_parsed.json
# Parsed and saved: br_articles_11_parsed.json
# Parsed and saved: br_articles_12_parsed.json
# Parsed and saved: br_articles_13_parsed.json
# Parsed and saved: br_articles_14_parsed.json
# Parsed and saved: br_articles_15_parsed.json
# Parsed and saved: br_articles_16_parsed.json
# Parsed and saved: br_articles_17_parsed.json
# Parsed and saved: br_articles_18_parsed.json
# Parsed and saved: br_articles_19_parsed.json
# Parsed and saved: br_articles_20_parsed.json
# Parsed and saved: br_articles_21_parsed.json
# Parsed and saved: br_articles_22_parsed.json
# Parsed and saved: br_articles_23_parsed.json
# Parsed and saved: br_articles_24_parsed.json
# Parsed and saved: br_articles_25_parsed.json
# Parsed and saved: br_articles_26_parsed.json
# Parsed and saved: br_articles_27_parsed.json
# Parsed and saved: br_articles_28_parsed.json
# Parsed and saved: br_articles_29_parsed.json
# Parsed and saved: br_articles_30_parsed.json
# Parsed and saved: br_articles_32_parsed.json
# Parsed and saved: br_articles_33_parsed.json
# Parsed and saved: br_articles_34_parsed.json
# Parsed and saved: br_articles_35_parsed.json
# Parsed and saved: br_articles_36_parsed.json
# Parsed and saved: br_articles_37_parsed.json
# Parsed and saved: br_articles_38_parsed.json
# Parsed and saved: br_articles_39_parsed.json
# Parsed and saved: br_articles_40_parsed.json
# Parsed and saved: br_articles_41_parsed.json
# Parsed and saved: br_articles_42_parsed.json
# Parsed and saved: br_articles_43_parsed.json
# Parsed and saved: br_articles_44_parsed.json
# Parsed and saved: br_articles_45_parsed.json
# Parsed and saved: br_articles_47_parsed.json
# Parsed and saved: br_articles_48_parsed.json
# Parsed and saved: br_articles_49_parsed.json
# Parsed and saved: ca_articles_0_parsed.json
# Parsed and saved: ca_articles_2_parsed.json
# Parsed and saved: ca_articles_3_parsed.json
# Parsed and saved: ca_articles_4_parsed.json
# Parsed and saved: ca_articles_5_parsed.json
# Parsed and saved: ca_articles_7_parsed.json
# Parsed and saved: ca_articles_8_parsed.json
# Parsed and saved: ca_articles_9_parsed.json
# Parsed and saved: ca_articles_11_parsed.json
# Parsed and saved: ca_articles_12_parsed.json
# Parsed and saved: ca_articles_13_parsed.json
# Parsed and saved: ca_articles_14_parsed.json
# Parsed and saved: ca_articles_15_parsed.json
# Parsed and saved: ca_articles_16_parsed.json
# Parsed and saved: ca_articles_17_parsed.json
# Parsed and saved: ca_articles_18_parsed.json
# Parsed and saved: ca_articles_20_parsed.json
# Parsed and saved: ca_articles_21_parsed.json
# Parsed and saved: ca_articles_22_parsed.json
# Parsed and saved: ca_articles_23_parsed.json
# Parsed and saved: ca_articles_25_parsed.json
# Parsed and saved: ca_articles_26_parsed.json
# Parsed and saved: ca_articles_27_parsed.json
# Parsed and saved: ca_articles_28_parsed.json
# Parsed and saved: ca_articles_33_parsed.json
# Parsed and saved: ca_articles_35_parsed.json
# Parsed and saved: ca_articles_36_parsed.json
# Parsed and saved: ca_articles_37_parsed.json
# Parsed and saved: ca_articles_38_parsed.json
# Parsed and saved: ca_articles_39_parsed.json
# Parsed and saved: ca_articles_41_parsed.json
# Parsed and saved: ca_articles_42_parsed.json
# Parsed and saved: ca_articles_43_parsed.json
# Parsed and saved: ca_articles_44_parsed.json
# Parsed and saved: ca_articles_45_parsed.json
# Parsed and saved: ca_articles_46_parsed.json
# Parsed and saved: ca_articles_47_parsed.json
# Parsed and saved: ca_articles_49_parsed.json
# Parsed and saved: ch_articles_0_parsed.json
# Parsed and saved: ch_articles_1_parsed.json
# Parsed and saved: ch_articles_2_parsed.json
# Parsed and saved: ch_articles_3_parsed.json
# Parsed and saved: ch_articles_4_parsed.json
# Parsed and saved: ch_articles_5_parsed.json
# Parsed and saved: ch_articles_6_parsed.json
# Parsed and saved: ch_articles_7_parsed.json
# Parsed and saved: ch_articles_8_parsed.json
# Parsed and saved: ch_articles_9_parsed.json
# Parsed and saved: ch_articles_10_parsed.json
# Parsed and saved: ch_articles_11_parsed.json
# Parsed and saved: ch_articles_12_parsed.json
# Parsed and saved: ch_articles_13_parsed.json
# Parsed and saved: ch_articles_14_parsed.json
# Parsed and saved: ch_articles_15_parsed.json
# Parsed and saved: ch_articles_16_parsed.json
# Parsed and saved: ch_articles_17_parsed.json
# Parsed and saved: ch_articles_18_parsed.json
# Parsed and saved: ch_articles_19_parsed.json
# Parsed and saved: ch_articles_20_parsed.json
# Parsed and saved: ch_articles_21_parsed.json
# Parsed and saved: ch_articles_22_parsed.json
# Parsed and saved: ch_articles_23_parsed.json
# Parsed and saved: ch_articles_24_parsed.json
# Parsed and saved: ch_articles_25_parsed.json
# Parsed and saved: ch_articles_26_parsed.json
# Parsed and saved: ch_articles_27_parsed.json
# Parsed and saved: ch_articles_28_parsed.json
# Parsed and saved: ch_articles_29_parsed.json
# Parsed and saved: ch_articles_30_parsed.json
# Parsed and saved: ch_articles_31_parsed.json
# Parsed and saved: ch_articles_32_parsed.json
# Parsed and saved: ch_articles_33_parsed.json
# Parsed and saved: ch_articles_34_parsed.json
# Parsed and saved: ch_articles_35_parsed.json
# Parsed and saved: ch_articles_36_parsed.json
# Parsed and saved: ch_articles_37_parsed.json
# Parsed and saved: ch_articles_38_parsed.json
# Parsed and saved: ch_articles_39_parsed.json
# Parsed and saved: ch_articles_40_parsed.json
# Parsed and saved: ch_articles_41_parsed.json
# Parsed and saved: ch_articles_42_parsed.json
# Parsed and saved: ch_articles_43_parsed.json
# Parsed and saved: ch_articles_44_parsed.json
# Parsed and saved: ch_articles_45_parsed.json
# Parsed and saved: ch_articles_46_parsed.json
# Parsed and saved: ch_articles_47_parsed.json
# Parsed and saved: ch_articles_48_parsed.json
# Parsed and saved: ch_articles_49_parsed.json
# Parsed and saved: cn_articles_0_parsed.json
# Parsed and saved: cn_articles_1_parsed.json
# Parsed and saved: cn_articles_3_parsed.json
# Parsed and saved: de_articles_0_parsed.json
# Parsed and saved: de_articles_10_parsed.json
# Parsed and saved: de_articles_14_parsed.json
# Parsed and saved: de_articles_17_parsed.json
# Parsed and saved: de_articles_19_parsed.json
# Parsed and saved: de_articles_20_parsed.json
# Parsed and saved: de_articles_24_parsed.json
# Parsed and saved: de_articles_30_parsed.json
# Parsed and saved: de_articles_34_parsed.json
# Parsed and saved: de_articles_37_parsed.json
# Parsed and saved: de_articles_39_parsed.json
# Parsed and saved: de_articles_40_parsed.json
# Parsed and saved: de_articles_41_parsed.json
# Parsed and saved: de_articles_44_parsed.json
# Parsed and saved: eg_articles_0_parsed.json
# Parsed and saved: eg_articles_1_parsed.json
# Parsed and saved: eg_articles_2_parsed.json
# Parsed and saved: eg_articles_3_parsed.json
# Parsed and saved: eg_articles_4_parsed.json
# Parsed and saved: eg_articles_5_parsed.json
# Parsed and saved: eg_articles_6_parsed.json
# Parsed and saved: eg_articles_7_parsed.json
# Parsed and saved: eg_articles_8_parsed.json
# Parsed and saved: eg_articles_9_parsed.json
# Parsed and saved: eg_articles_10_parsed.json
# Parsed and saved: es_articles_1_parsed.json
# Parsed and saved: es_articles_2_parsed.json
# Parsed and saved: es_articles_5_parsed.json
# Parsed and saved: es_articles_7_parsed.json
# Parsed and saved: es_articles_8_parsed.json
# Parsed and saved: es_articles_9_parsed.json
# Parsed and saved: es_articles_10_parsed.json
# Parsed and saved: es_articles_11_parsed.json
# Parsed and saved: es_articles_13_parsed.json
# Parsed and saved: fr_articles_0_parsed.json
# Parsed and saved: fr_articles_1_parsed.json
# Parsed and saved: fr_articles_2_parsed.json
# Parsed and saved: fr_articles_3_parsed.json
# Parsed and saved: fr_articles_4_parsed.json
# Parsed and saved: fr_articles_5_parsed.json
# Parsed and saved: fr_articles_6_parsed.json
# Parsed and saved: fr_articles_9_parsed.json
# Parsed and saved: fr_articles_11_parsed.json
# Parsed and saved: fr_articles_12_parsed.json
# Parsed and saved: fr_articles_13_parsed.json
# Parsed and saved: fr_articles_14_parsed.json
# Parsed and saved: fr_articles_15_parsed.json
# Parsed and saved: fr_articles_16_parsed.json
# Parsed and saved: fr_articles_17_parsed.json
# Parsed and saved: fr_articles_18_parsed.json
# Parsed and saved: fr_articles_19_parsed.json
# Parsed and saved: fr_articles_20_parsed.json
# Parsed and saved: fr_articles_21_parsed.json
# Parsed and saved: fr_articles_22_parsed.json
# Parsed and saved: fr_articles_23_parsed.json
# Parsed and saved: fr_articles_24_parsed.json
# Parsed and saved: fr_articles_25_parsed.json
# Parsed and saved: fr_articles_26_parsed.json
# Parsed and saved: fr_articles_27_parsed.json
# Parsed and saved: fr_articles_28_parsed.json
# Parsed and saved: fr_articles_29_parsed.json
# Parsed and saved: fr_articles_30_parsed.json
# Parsed and saved: fr_articles_31_parsed.json
# Parsed and saved: fr_articles_32_parsed.json
# Parsed and saved: fr_articles_34_parsed.json
# Parsed and saved: fr_articles_37_parsed.json
# Parsed and saved: fr_articles_38_parsed.json
# Parsed and saved: fr_articles_39_parsed.json
# Parsed and saved: fr_articles_40_parsed.json
# Parsed and saved: fr_articles_41_parsed.json
# Parsed and saved: fr_articles_42_parsed.json
# Parsed and saved: fr_articles_43_parsed.json
# Parsed and saved: fr_articles_45_parsed.json
# Parsed and saved: fr_articles_46_parsed.json
# Parsed and saved: fr_articles_47_parsed.json
# Parsed and saved: gb_articles_0_parsed.json
# Parsed and saved: gb_articles_1_parsed.json
# Parsed and saved: gb_articles_2_parsed.json
# Parsed and saved: gb_articles_3_parsed.json
# Parsed and saved: gb_articles_4_parsed.json
# Parsed and saved: gb_articles_5_parsed.json
# Parsed and saved: gb_articles_6_parsed.json
# Parsed and saved: gb_articles_7_parsed.json
# Parsed and saved: gb_articles_8_parsed.json
# Parsed and saved: gb_articles_9_parsed.json
# Parsed and saved: gb_articles_10_parsed.json
# Parsed and saved: gb_articles_11_parsed.json
# Parsed and saved: gb_articles_12_parsed.json
# Parsed and saved: gb_articles_13_parsed.json
# Parsed and saved: gb_articles_14_parsed.json
# Parsed and saved: gb_articles_15_parsed.json
# Parsed and saved: gb_articles_16_parsed.json
# Parsed and saved: gb_articles_17_parsed.json
# Parsed and saved: gb_articles_18_parsed.json
# Parsed and saved: gb_articles_19_parsed.json
# Parsed and saved: gb_articles_20_parsed.json
# Parsed and saved: gb_articles_21_parsed.json
# Parsed and saved: gb_articles_22_parsed.json
# Parsed and saved: gb_articles_23_parsed.json
# Parsed and saved: gb_articles_24_parsed.json
# Parsed and saved: gb_articles_25_parsed.json
# Parsed and saved: gb_articles_26_parsed.json
# Parsed and saved: gb_articles_27_parsed.json
# Parsed and saved: gb_articles_28_parsed.json
# Parsed and saved: gb_articles_29_parsed.json
# Parsed and saved: gb_articles_30_parsed.json
# Parsed and saved: gb_articles_31_parsed.json
# Parsed and saved: gb_articles_32_parsed.json
# Parsed and saved: gb_articles_33_parsed.json
# Parsed and saved: gb_articles_34_parsed.json
# Parsed and saved: gb_articles_35_parsed.json
# Parsed and saved: gb_articles_36_parsed.json
# Parsed and saved: gb_articles_37_parsed.json
# Parsed and saved: gb_articles_38_parsed.json
# Parsed and saved: gb_articles_39_parsed.json
# Parsed and saved: gb_articles_40_parsed.json
# Parsed and saved: gb_articles_41_parsed.json
# Parsed and saved: gb_articles_42_parsed.json
# Parsed and saved: gb_articles_43_parsed.json
# Parsed and saved: gb_articles_44_parsed.json
# Parsed and saved: gb_articles_45_parsed.json
# Parsed and saved: gb_articles_46_parsed.json
# Parsed and saved: gb_articles_47_parsed.json
# Parsed and saved: gb_articles_48_parsed.json
# Parsed and saved: gb_articles_49_parsed.json
# Parsed and saved: gr_articles_0_parsed.json
# Parsed and saved: gr_articles_1_parsed.json
# Parsed and saved: gr_articles_2_parsed.json
# Parsed and saved: gr_articles_4_parsed.json
# Parsed and saved: gr_articles_5_parsed.json
# Parsed and saved: gr_articles_7_parsed.json
# Parsed and saved: gr_articles_8_parsed.json
# Parsed and saved: gr_articles_9_parsed.json
# Parsed and saved: gr_articles_10_parsed.json
# Parsed and saved: gr_articles_12_parsed.json
# Parsed and saved: gr_articles_14_parsed.json
# Parsed and saved: gr_articles_16_parsed.json
# Parsed and saved: gr_articles_18_parsed.json
# Parsed and saved: gr_articles_20_parsed.json
# Parsed and saved: gr_articles_21_parsed.json
# Parsed and saved: gr_articles_22_parsed.json
# Parsed and saved: gr_articles_23_parsed.json
# Parsed and saved: gr_articles_27_parsed.json
# Parsed and saved: gr_articles_29_parsed.json
# Parsed and saved: gr_articles_30_parsed.json
# Parsed and saved: gr_articles_31_parsed.json
# Parsed and saved: gr_articles_32_parsed.json
# Parsed and saved: gr_articles_34_parsed.json
# Parsed and saved: gr_articles_35_parsed.json
# Parsed and saved: gr_articles_36_parsed.json
# Parsed and saved: gr_articles_37_parsed.json
# Parsed and saved: gr_articles_38_parsed.json
# Parsed and saved: gr_articles_43_parsed.json
# Parsed and saved: gr_articles_44_parsed.json
# Parsed and saved: hk_articles_0_parsed.json
# Parsed and saved: hk_articles_1_parsed.json
# Parsed and saved: hk_articles_2_parsed.json
# Parsed and saved: hk_articles_3_parsed.json
# Parsed and saved: ie_articles_5_parsed.json
# Parsed and saved: ie_articles_10_parsed.json
# Parsed and saved: ie_articles_12_parsed.json
# Parsed and saved: ie_articles_13_parsed.json
# Parsed and saved: ie_articles_14_parsed.json
# Parsed and saved: ie_articles_15_parsed.json
# Parsed and saved: ie_articles_18_parsed.json
# Parsed and saved: ie_articles_19_parsed.json
# Parsed and saved: ie_articles_20_parsed.json
# Parsed and saved: ie_articles_23_parsed.json
# Parsed and saved: ie_articles_26_parsed.json
# Parsed and saved: ie_articles_29_parsed.json
# Parsed and saved: ie_articles_30_parsed.json
# Parsed and saved: ie_articles_31_parsed.json
# Parsed and saved: ie_articles_33_parsed.json
# Parsed and saved: ie_articles_34_parsed.json
# Parsed and saved: ie_articles_38_parsed.json
# Parsed and saved: ie_articles_39_parsed.json
# Parsed and saved: ie_articles_40_parsed.json
# Parsed and saved: ie_articles_42_parsed.json
# Parsed and saved: ie_articles_43_parsed.json
# Parsed and saved: ie_articles_44_parsed.json
# Parsed and saved: ie_articles_46_parsed.json
# Parsed and saved: ie_articles_49_parsed.json
# Parsed and saved: in_articles_1_parsed.json
# Parsed and saved: in_articles_3_parsed.json
# Parsed and saved: in_articles_4_parsed.json
# Parsed and saved: in_articles_5_parsed.json
# Parsed and saved: in_articles_6_parsed.json
# Parsed and saved: in_articles_7_parsed.json
# Parsed and saved: in_articles_9_parsed.json
# Parsed and saved: in_articles_12_parsed.json
# Parsed and saved: in_articles_14_parsed.json
# Parsed and saved: in_articles_15_parsed.json
# Parsed and saved: in_articles_16_parsed.json
# Parsed and saved: in_articles_17_parsed.json
# Parsed and saved: in_articles_18_parsed.json
# Parsed and saved: in_articles_19_parsed.json
# Parsed and saved: in_articles_20_parsed.json
# Parsed and saved: in_articles_21_parsed.json
# Parsed and saved: in_articles_23_parsed.json
# Parsed and saved: in_articles_24_parsed.json
# Parsed and saved: in_articles_25_parsed.json
# Parsed and saved: in_articles_27_parsed.json
# Parsed and saved: in_articles_28_parsed.json
# Parsed and saved: in_articles_29_parsed.json
# Parsed and saved: in_articles_30_parsed.json
# Parsed and saved: in_articles_31_parsed.json
# Parsed and saved: in_articles_32_parsed.json
# Parsed and saved: in_articles_33_parsed.json
# Parsed and saved: in_articles_35_parsed.json
# Parsed and saved: in_articles_36_parsed.json
# Parsed and saved: in_articles_37_parsed.json
# Parsed and saved: in_articles_38_parsed.json
# Parsed and saved: in_articles_40_parsed.json
# Parsed and saved: in_articles_41_parsed.json
# Parsed and saved: in_articles_42_parsed.json
# Parsed and saved: in_articles_43_parsed.json
# Parsed and saved: in_articles_45_parsed.json
# Parsed and saved: in_articles_46_parsed.json
# Parsed and saved: in_articles_48_parsed.json
# Parsed and saved: in_articles_49_parsed.json
# Parsed and saved: it_articles_1_parsed.json
# Parsed and saved: it_articles_3_parsed.json
# Parsed and saved: it_articles_4_parsed.json
# Parsed and saved: it_articles_5_parsed.json
# Parsed and saved: it_articles_6_parsed.json
# Parsed and saved: it_articles_8_parsed.json
# Parsed and saved: it_articles_9_parsed.json
# Parsed and saved: it_articles_11_parsed.json
# Parsed and saved: it_articles_12_parsed.json
# Parsed and saved: it_articles_13_parsed.json
# Parsed and saved: it_articles_14_parsed.json
# Parsed and saved: it_articles_18_parsed.json
# Parsed and saved: it_articles_20_parsed.json
# Parsed and saved: it_articles_21_parsed.json
# Parsed and saved: it_articles_22_parsed.json
# Parsed and saved: it_articles_24_parsed.json
# Parsed and saved: it_articles_27_parsed.json
# Parsed and saved: it_articles_29_parsed.json
# Parsed and saved: it_articles_30_parsed.json
# Parsed and saved: it_articles_31_parsed.json
# Parsed and saved: it_articles_32_parsed.json
# Parsed and saved: it_articles_33_parsed.json
# Parsed and saved: it_articles_36_parsed.json
# Parsed and saved: it_articles_38_parsed.json
# Parsed and saved: it_articles_39_parsed.json
# Parsed and saved: it_articles_41_parsed.json
# Parsed and saved: it_articles_42_parsed.json
# Parsed and saved: it_articles_43_parsed.json
# Parsed and saved: it_articles_44_parsed.json
# Parsed and saved: it_articles_46_parsed.json
# Parsed and saved: it_articles_47_parsed.json
# Parsed and saved: it_articles_49_parsed.json
# Parsed and saved: jp_articles_0_parsed.json
# Parsed and saved: jp_articles_1_parsed.json
# Parsed and saved: jp_articles_2_parsed.json
# Parsed and saved: jp_articles_3_parsed.json
# Parsed and saved: jp_articles_4_parsed.json
# Parsed and saved: jp_articles_5_parsed.json
# Parsed and saved: jp_articles_6_parsed.json
# Parsed and saved: jp_articles_7_parsed.json
# Parsed and saved: jp_articles_8_parsed.json
# Parsed and saved: jp_articles_9_parsed.json
# Parsed and saved: jp_articles_10_parsed.json
# Parsed and saved: jp_articles_11_parsed.json
# Parsed and saved: jp_articles_12_parsed.json
# Parsed and saved: jp_articles_13_parsed.json
# Parsed and saved: nl_articles_0_parsed.json
# Parsed and saved: nl_articles_1_parsed.json
# Parsed and saved: no_articles_0_parsed.json
# Parsed and saved: no_articles_1_parsed.json
# Parsed and saved: no_articles_2_parsed.json
# Parsed and saved: no_articles_5_parsed.json
# Parsed and saved: no_articles_6_parsed.json
# Parsed and saved: no_articles_7_parsed.json
# Parsed and saved: no_articles_8_parsed.json
# Parsed and saved: no_articles_10_parsed.json
# Parsed and saved: no_articles_11_parsed.json
# Parsed and saved: no_articles_12_parsed.json
# Parsed and saved: no_articles_13_parsed.json
# Parsed and saved: no_articles_14_parsed.json
# Parsed and saved: no_articles_15_parsed.json
# Parsed and saved: no_articles_16_parsed.json
# Parsed and saved: no_articles_17_parsed.json
# Parsed and saved: no_articles_19_parsed.json
# Parsed and saved: no_articles_21_parsed.json
# Parsed and saved: no_articles_22_parsed.json
# Parsed and saved: no_articles_23_parsed.json
# Parsed and saved: no_articles_25_parsed.json
# Parsed and saved: no_articles_26_parsed.json
# Parsed and saved: no_articles_27_parsed.json
# Parsed and saved: pe_articles_0_parsed.json
# Parsed and saved: pe_articles_1_parsed.json
# Parsed and saved: pe_articles_2_parsed.json
# Parsed and saved: pe_articles_3_parsed.json
# Parsed and saved: pe_articles_4_parsed.json
# Parsed and saved: pe_articles_5_parsed.json
# Parsed and saved: pe_articles_6_parsed.json
# Parsed and saved: pe_articles_7_parsed.json
# Parsed and saved: pe_articles_8_parsed.json
# Parsed and saved: pe_articles_9_parsed.json
# Parsed and saved: pe_articles_10_parsed.json
# Parsed and saved: pe_articles_11_parsed.json
# Parsed and saved: pe_articles_12_parsed.json
# Parsed and saved: pe_articles_13_parsed.json
# Parsed and saved: pe_articles_14_parsed.json
# Parsed and saved: pe_articles_16_parsed.json
# Parsed and saved: pe_articles_17_parsed.json
# Parsed and saved: ph_articles_0_parsed.json
# Parsed and saved: ph_articles_1_parsed.json
# Parsed and saved: ph_articles_2_parsed.json
# Parsed and saved: ph_articles_3_parsed.json
# Parsed and saved: ph_articles_4_parsed.json
# Parsed and saved: ph_articles_5_parsed.json
# Parsed and saved: ph_articles_6_parsed.json
# Parsed and saved: ph_articles_7_parsed.json
# Parsed and saved: ph_articles_8_parsed.json
# Parsed and saved: ph_articles_9_parsed.json
# Parsed and saved: ph_articles_10_parsed.json
# Parsed and saved: ph_articles_11_parsed.json
# Parsed and saved: ph_articles_12_parsed.json
# Parsed and saved: ph_articles_13_parsed.json
# Parsed and saved: ph_articles_14_parsed.json
# Parsed and saved: ph_articles_15_parsed.json
# Parsed and saved: ph_articles_16_parsed.json
# Parsed and saved: ph_articles_17_parsed.json
# Parsed and saved: ph_articles_18_parsed.json
# Parsed and saved: ph_articles_19_parsed.json
# Parsed and saved: ph_articles_20_parsed.json
# Parsed and saved: ph_articles_21_parsed.json
# Parsed and saved: ph_articles_22_parsed.json
# Parsed and saved: ph_articles_23_parsed.json
# Parsed and saved: ph_articles_24_parsed.json
# Parsed and saved: ph_articles_25_parsed.json
# Parsed and saved: ph_articles_26_parsed.json
# Parsed and saved: ph_articles_27_parsed.json
# Parsed and saved: ph_articles_28_parsed.json
# Parsed and saved: ph_articles_29_parsed.json
# Parsed and saved: ph_articles_30_parsed.json
# Parsed and saved: ph_articles_31_parsed.json
# Parsed and saved: ph_articles_32_parsed.json
# Parsed and saved: ph_articles_33_parsed.json
# Parsed and saved: ph_articles_34_parsed.json
# Parsed and saved: ph_articles_35_parsed.json
# Parsed and saved: ph_articles_36_parsed.json
# Parsed and saved: ph_articles_37_parsed.json
# Parsed and saved: ph_articles_38_parsed.json
# Parsed and saved: ph_articles_39_parsed.json
# Parsed and saved: ph_articles_40_parsed.json
# Parsed and saved: ph_articles_41_parsed.json
# Parsed and saved: ph_articles_42_parsed.json
# Parsed and saved: ph_articles_43_parsed.json
# Parsed and saved: ph_articles_44_parsed.json
# Parsed and saved: ph_articles_45_parsed.json
# Parsed and saved: ph_articles_46_parsed.json
# Parsed and saved: ph_articles_47_parsed.json
# Parsed and saved: ph_articles_48_parsed.json
# Parsed and saved: ph_articles_49_parsed.json
# Parsed and saved: pk_articles_0_parsed.json
# Parsed and saved: pk_articles_1_parsed.json
# Parsed and saved: pk_articles_2_parsed.json
# Parsed and saved: pk_articles_3_parsed.json
# Parsed and saved: pk_articles_4_parsed.json
# Parsed and saved: pk_articles_5_parsed.json
# Parsed and saved: pk_articles_7_parsed.json
# Parsed and saved: pk_articles_8_parsed.json
# Parsed and saved: pk_articles_9_parsed.json
# Parsed and saved: pk_articles_10_parsed.json
# Parsed and saved: pk_articles_11_parsed.json
# Parsed and saved: pk_articles_12_parsed.json
# Parsed and saved: pk_articles_13_parsed.json
# Parsed and saved: pk_articles_14_parsed.json
# Parsed and saved: pk_articles_15_parsed.json
# Parsed and saved: pk_articles_16_parsed.json
# Parsed and saved: pk_articles_17_parsed.json
# Parsed and saved: pk_articles_18_parsed.json
# Parsed and saved: pk_articles_19_parsed.json
# Parsed and saved: pk_articles_20_parsed.json
# Parsed and saved: pk_articles_21_parsed.json
# Parsed and saved: pk_articles_22_parsed.json
# Parsed and saved: pk_articles_23_parsed.json
# Parsed and saved: pk_articles_24_parsed.json
# Parsed and saved: pk_articles_25_parsed.json
# Parsed and saved: pk_articles_26_parsed.json
# Parsed and saved: pk_articles_27_parsed.json
# Parsed and saved: pk_articles_28_parsed.json
# Parsed and saved: pk_articles_29_parsed.json
# Parsed and saved: pk_articles_30_parsed.json
# Parsed and saved: pk_articles_31_parsed.json
# Parsed and saved: pk_articles_32_parsed.json
# Parsed and saved: pk_articles_33_parsed.json
# Parsed and saved: pk_articles_34_parsed.json
# Parsed and saved: pk_articles_35_parsed.json
# Parsed and saved: pk_articles_36_parsed.json
# Parsed and saved: pk_articles_37_parsed.json
# Parsed and saved: pk_articles_38_parsed.json
# Parsed and saved: pk_articles_39_parsed.json
# Parsed and saved: pk_articles_40_parsed.json
# Parsed and saved: pk_articles_41_parsed.json
# Parsed and saved: pk_articles_42_parsed.json
# Parsed and saved: pk_articles_43_parsed.json
# Parsed and saved: pk_articles_44_parsed.json
# Parsed and saved: pk_articles_45_parsed.json
# Parsed and saved: pk_articles_46_parsed.json
# Parsed and saved: pk_articles_47_parsed.json
# Parsed and saved: pk_articles_48_parsed.json
# Parsed and saved: pk_articles_49_parsed.json
# Parsed and saved: pt_articles_0_parsed.json
# Parsed and saved: pt_articles_1_parsed.json
# Parsed and saved: pt_articles_2_parsed.json
# Parsed and saved: pt_articles_3_parsed.json
# Parsed and saved: pt_articles_5_parsed.json
# Parsed and saved: pt_articles_6_parsed.json
# Parsed and saved: pt_articles_9_parsed.json
# Parsed and saved: pt_articles_10_parsed.json
# Parsed and saved: pt_articles_11_parsed.json
# Parsed and saved: pt_articles_12_parsed.json
# Parsed and saved: pt_articles_13_parsed.json
# Parsed and saved: pt_articles_14_parsed.json
# Parsed and saved: pt_articles_15_parsed.json
# Parsed and saved: pt_articles_16_parsed.json
# Parsed and saved: pt_articles_17_parsed.json
# Parsed and saved: pt_articles_18_parsed.json
# Parsed and saved: pt_articles_21_parsed.json
# Parsed and saved: pt_articles_22_parsed.json
# Parsed and saved: pt_articles_23_parsed.json
# Parsed and saved: pt_articles_24_parsed.json
# Parsed and saved: pt_articles_25_parsed.json
# Parsed and saved: pt_articles_26_parsed.json
# Parsed and saved: pt_articles_27_parsed.json
# Parsed and saved: pt_articles_28_parsed.json
# Parsed and saved: pt_articles_29_parsed.json
# Parsed and saved: pt_articles_31_parsed.json
# Parsed and saved: pt_articles_32_parsed.json
# Parsed and saved: pt_articles_33_parsed.json
# Parsed and saved: pt_articles_34_parsed.json
# Parsed and saved: pt_articles_35_parsed.json
# Parsed and saved: pt_articles_36_parsed.json
# Parsed and saved: pt_articles_37_parsed.json
# Parsed and saved: pt_articles_38_parsed.json
# Parsed and saved: pt_articles_39_parsed.json
# Parsed and saved: pt_articles_40_parsed.json
# Parsed and saved: pt_articles_41_parsed.json
# Parsed and saved: pt_articles_45_parsed.json
# Parsed and saved: pt_articles_46_parsed.json
# Parsed and saved: pt_articles_47_parsed.json
# Parsed and saved: pt_articles_48_parsed.json
# Parsed and saved: pt_articles_49_parsed.json
# Parsed and saved: ro_articles_0_parsed.json
# Parsed and saved: ro_articles_1_parsed.json
# Parsed and saved: ro_articles_2_parsed.json
# Parsed and saved: ro_articles_3_parsed.json
# Parsed and saved: ro_articles_4_parsed.json
# Parsed and saved: ro_articles_5_parsed.json
# Parsed and saved: ro_articles_6_parsed.json
# Parsed and saved: ro_articles_7_parsed.json
# Parsed and saved: ro_articles_8_parsed.json
# Parsed and saved: ro_articles_9_parsed.json
# Parsed and saved: ro_articles_11_parsed.json
# Parsed and saved: ro_articles_12_parsed.json
# Parsed and saved: ro_articles_13_parsed.json
# Parsed and saved: ro_articles_15_parsed.json
# Parsed and saved: ro_articles_17_parsed.json
# Parsed and saved: ro_articles_22_parsed.json
# Parsed and saved: ro_articles_23_parsed.json
# Parsed and saved: ro_articles_26_parsed.json
# Parsed and saved: ro_articles_27_parsed.json
# Parsed and saved: ro_articles_28_parsed.json
# Parsed and saved: ro_articles_29_parsed.json
# Parsed and saved: ro_articles_31_parsed.json
# Parsed and saved: ro_articles_32_parsed.json
# Parsed and saved: ro_articles_33_parsed.json
# Parsed and saved: ro_articles_34_parsed.json
# Parsed and saved: ro_articles_35_parsed.json
# Parsed and saved: ro_articles_36_parsed.json
# Parsed and saved: ro_articles_37_parsed.json
# Parsed and saved: ro_articles_38_parsed.json
# Parsed and saved: ro_articles_39_parsed.json
# Parsed and saved: ro_articles_40_parsed.json
# Parsed and saved: ro_articles_41_parsed.json
# Parsed and saved: ro_articles_42_parsed.json
# Parsed and saved: ro_articles_43_parsed.json
# Parsed and saved: ro_articles_45_parsed.json
# Parsed and saved: ro_articles_47_parsed.json
# Parsed and saved: ro_articles_48_parsed.json
# Parsed and saved: ro_articles_49_parsed.json
# Parsed and saved: ru_articles_0_parsed.json
# Parsed and saved: ru_articles_1_parsed.json
# Parsed and saved: ru_articles_2_parsed.json
# Parsed and saved: ru_articles_3_parsed.json
# Parsed and saved: ru_articles_4_parsed.json
# Parsed and saved: ru_articles_5_parsed.json
# Parsed and saved: ru_articles_6_parsed.json
# Parsed and saved: ru_articles_7_parsed.json
# Parsed and saved: ru_articles_8_parsed.json
# Parsed and saved: ru_articles_9_parsed.json
# Parsed and saved: ru_articles_10_parsed.json
# Parsed and saved: ru_articles_11_parsed.json
# Parsed and saved: ru_articles_12_parsed.json
# Parsed and saved: ru_articles_13_parsed.json
# Parsed and saved: ru_articles_14_parsed.json
# Parsed and saved: ru_articles_15_parsed.json
# Parsed and saved: ru_articles_16_parsed.json
# Parsed and saved: ru_articles_17_parsed.json
# Parsed and saved: ru_articles_18_parsed.json
# Parsed and saved: ru_articles_19_parsed.json
# Parsed and saved: ru_articles_20_parsed.json
# Parsed and saved: ru_articles_21_parsed.json
# Parsed and saved: ru_articles_22_parsed.json
# Parsed and saved: ru_articles_23_parsed.json
# Parsed and saved: ru_articles_24_parsed.json
# Parsed and saved: ru_articles_25_parsed.json
# Parsed and saved: ru_articles_26_parsed.json
# Parsed and saved: ru_articles_27_parsed.json
# Parsed and saved: ru_articles_28_parsed.json
# Parsed and saved: ru_articles_29_parsed.json
# Parsed and saved: ru_articles_30_parsed.json
# Parsed and saved: ru_articles_31_parsed.json
# Parsed and saved: ru_articles_32_parsed.json
# Parsed and saved: ru_articles_33_parsed.json
# Parsed and saved: ru_articles_34_parsed.json
# Parsed and saved: ru_articles_35_parsed.json
# Parsed and saved: ru_articles_36_parsed.json
# Parsed and saved: ru_articles_37_parsed.json
# Parsed and saved: ru_articles_38_parsed.json
# Parsed and saved: ru_articles_39_parsed.json
# Parsed and saved: ru_articles_40_parsed.json
# Parsed and saved: ru_articles_41_parsed.json
# Parsed and saved: ru_articles_42_parsed.json
# Parsed and saved: ru_articles_43_parsed.json
# Parsed and saved: ru_articles_44_parsed.json
# Parsed and saved: ru_articles_45_parsed.json
# Parsed and saved: ru_articles_46_parsed.json
# Parsed and saved: ru_articles_47_parsed.json
# Parsed and saved: ru_articles_48_parsed.json
# Parsed and saved: ru_articles_49_parsed.json
# Parsed and saved: se_articles_1_parsed.json
# Parsed and saved: se_articles_2_parsed.json
# Parsed and saved: se_articles_3_parsed.json
# Parsed and saved: se_articles_4_parsed.json
# Parsed and saved: se_articles_8_parsed.json
# Parsed and saved: se_articles_9_parsed.json
# Parsed and saved: se_articles_10_parsed.json
# Parsed and saved: se_articles_12_parsed.json
# Parsed and saved: se_articles_13_parsed.json
# Parsed and saved: se_articles_14_parsed.json
# Parsed and saved: sg_articles_0_parsed.json
# Parsed and saved: sg_articles_1_parsed.json
# Parsed and saved: sg_articles_2_parsed.json
# Parsed and saved: sg_articles_3_parsed.json
# Parsed and saved: sg_articles_5_parsed.json
# Parsed and saved: sg_articles_6_parsed.json
# Parsed and saved: sg_articles_7_parsed.json
# Parsed and saved: sg_articles_8_parsed.json
# Parsed and saved: sg_articles_9_parsed.json
# Parsed and saved: sg_articles_10_parsed.json
# Parsed and saved: sg_articles_11_parsed.json
# Parsed and saved: sg_articles_12_parsed.json
# Parsed and saved: sg_articles_13_parsed.json
# Parsed and saved: sg_articles_14_parsed.json
# Parsed and saved: sg_articles_15_parsed.json
# Parsed and saved: sg_articles_16_parsed.json
# Parsed and saved: sg_articles_17_parsed.json
# Parsed and saved: sg_articles_18_parsed.json
# Parsed and saved: sg_articles_19_parsed.json
# Parsed and saved: sg_articles_20_parsed.json
# Parsed and saved: sg_articles_21_parsed.json
# Parsed and saved: sg_articles_22_parsed.json
# Parsed and saved: sg_articles_23_parsed.json
# Parsed and saved: sg_articles_24_parsed.json
# Parsed and saved: sg_articles_25_parsed.json
# Parsed and saved: sg_articles_27_parsed.json
# Parsed and saved: sg_articles_28_parsed.json
# Parsed and saved: sg_articles_29_parsed.json
# Parsed and saved: sg_articles_30_parsed.json
# Parsed and saved: sg_articles_31_parsed.json
# Parsed and saved: sg_articles_32_parsed.json
# Parsed and saved: sg_articles_33_parsed.json
# Parsed and saved: sg_articles_34_parsed.json
# Parsed and saved: sg_articles_35_parsed.json
# Parsed and saved: sg_articles_36_parsed.json
# Parsed and saved: sg_articles_37_parsed.json
# Parsed and saved: sg_articles_38_parsed.json
# Parsed and saved: sg_articles_39_parsed.json
# Parsed and saved: sg_articles_40_parsed.json
# Parsed and saved: sg_articles_41_parsed.json
# Parsed and saved: sg_articles_42_parsed.json
# Parsed and saved: sg_articles_43_parsed.json
# Parsed and saved: sg_articles_44_parsed.json
# Parsed and saved: sg_articles_45_parsed.json
# Parsed and saved: sg_articles_46_parsed.json
# Parsed and saved: sg_articles_49_parsed.json
# Parsed and saved: tw_articles_0_parsed.json
# Parsed and saved: tw_articles_1_parsed.json
# Parsed and saved: tw_articles_2_parsed.json
# Parsed and saved: tw_articles_3_parsed.json
# Parsed and saved: tw_articles_4_parsed.json
# Parsed and saved: tw_articles_7_parsed.json
# Parsed and saved: tw_articles_8_parsed.json
# Parsed and saved: tw_articles_9_parsed.json
# Parsed and saved: tw_articles_10_parsed.json
# Parsed and saved: tw_articles_12_parsed.json
# Parsed and saved: tw_articles_13_parsed.json
# Parsed and saved: tw_articles_14_parsed.json
# Parsed and saved: tw_articles_18_parsed.json
# Parsed and saved: tw_articles_21_parsed.json
# Parsed and saved: tw_articles_25_parsed.json
# Parsed and saved: us_articles_1_parsed.json
# Parsed and saved: us_articles_3_parsed.json
# Parsed and saved: us_articles_4_parsed.json
# Parsed and saved: us_articles_5_parsed.json
# Parsed and saved: us_articles_6_parsed.json
# Parsed and saved: us_articles_7_parsed.json
# Parsed and saved: us_articles_9_parsed.json
# Parsed and saved: us_articles_10_parsed.json
# Parsed and saved: us_articles_11_parsed.json
# Parsed and saved: us_articles_12_parsed.json
# Parsed and saved: us_articles_14_parsed.json
# Parsed and saved: us_articles_15_parsed.json
# Parsed and saved: us_articles_16_parsed.json
# Parsed and saved: us_articles_17_parsed.json
# Parsed and saved: us_articles_18_parsed.json
# Parsed and saved: us_articles_19_parsed.json
# Parsed and saved: us_articles_20_parsed.json
# Parsed and saved: us_articles_27_parsed.json
# Parsed and saved: us_articles_28_parsed.json
# Parsed and saved: us_articles_29_parsed.json
# Parsed and saved: us_articles_31_parsed.json
# Parsed and saved: us_articles_32_parsed.json
# Parsed and saved: us_articles_33_parsed.json
# Parsed and saved: us_articles_34_parsed.json
# Parsed and saved: us_articles_35_parsed.json
# Parsed and saved: us_articles_36_parsed.json
# Parsed and saved: us_articles_37_parsed.json
# Parsed and saved: us_articles_39_parsed.json
# Parsed and saved: us_articles_40_parsed.json
# Parsed and saved: us_articles_41_parsed.json
# Parsed and saved: us_articles_42_parsed.json
# Parsed and saved: us_articles_43_parsed.json
# Parsed and saved: us_articles_44_parsed.json
# Parsed and saved: us_articles_46_parsed.json
# Parsed and saved: us_articles_47_parsed.json
# Parsed and saved: us_articles_48_parsed.json
# Parsed and saved: us_articles_49_parsed.json
