# %%
import os
import json
import re
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Олег\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
input_dir = "parsed_articles"
output_dir = "cleaned_articles"
os.makedirs(output_dir, exist_ok=True)

# %%
def clean_text(text):
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"<.*?>", "", text)
    text = re.sub(r"\s+", " ", text)
    text = text.strip()
    return text

# %%
def filter_sentences(sentences):
    clean_sentences = []
    for s in sentences:
        s = s.strip()
        if len(s) > 20 and re.search(r"[a-zA-Z]", s):
            clean_sentences.append(s)
    return clean_sentences

# %%
for filename in os.listdir(input_dir):
    if not filename.endswith("_parsed.json"):
        continue

    with open(os.path.join(input_dir, filename), 
              "r", 
              encoding="utf-8") as f:
        data = json.load(f)

    translated_text = data.get("translated_text_en", "")
    if not translated_text:
        continue

    cleaned = clean_text(translated_text)
    sentences = sent_tokenize(cleaned)
    filtered_sentences = filter_sentences(sentences)

    output_data = {
        "title": data.get("title"),
        "published_date": data.get("published_date"),
        "url": data.get("url"),
        "original_language": data.get("original_language"),
        "cleaned_sentences": filtered_sentences
    }

    base_name = os.path.splitext(filename)[0].replace("_parsed", 
                                                      "_cleaned")
    output_path = os.path.join(output_dir, f"{base_name}.json")

    with open(output_path, "w", encoding="utf-8") as out_file:
        json.dump(output_data, out_file, ensure_ascii=False, indent=2)

    print(f"Cleaned and saved: {output_path}")
# Out:
# Cleaned and saved: cleaned_articles\au_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\au_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\br_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\ca_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\ch_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\de_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\eg_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\eg_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\eg_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\eg_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\es_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\fr_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\gb_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\gr_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\hk_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\hk_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\ie_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\in_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\it_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\jp_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\nl_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\nl_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\no_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\pe_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\ph_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\pk_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\pt_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\ro_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_26_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\ru_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\se_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_0_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_13_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_21_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_22_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_23_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_24_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_25_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_2_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_30_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_38_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_45_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_8_cleaned.json
# Cleaned and saved: cleaned_articles\sg_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\tw_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\tw_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\tw_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\tw_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\tw_articles_9_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_10_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_11_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_12_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_14_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_15_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_16_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_17_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_18_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_19_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_1_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_20_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_27_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_28_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_29_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_31_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_32_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_33_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_34_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_35_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_36_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_37_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_39_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_3_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_40_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_41_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_42_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_43_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_44_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_46_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_47_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_48_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_49_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_4_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_5_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_6_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_7_cleaned.json
# Cleaned and saved: cleaned_articles\us_articles_9_cleaned.json
